# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: Midnight, March 22nd (with usual 2 hour grace period and late policy)
#
# ### Overview
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 7 graded problems, each worth 7 points, and you get 1 point free if you complete the assignment.

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display
 
# Data source
from sklearn.datasets import fetch_openml

 
# scikit-learn core tools 
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

 
# Import model 
from sklearn.ensemble import HistGradientBoostingClassifier
 
# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report
 
# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model 

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1             
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3               
    max_depth=None,               
    min_samples_leaf=20,          
    l2_regularization=0.0,        

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
# Your code here

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_seed
)

scores = cross_val_score(
    HGBC_model, 
    X, y,
    cv=skf,
    scoring="f1"
)

mean = scores.mean()
std = scores.std()

print(f"Mean F1: {mean:.4f}")
print(f"Std Dev: {std:.4f}")
# Out:
# Mean F1: 0.7130
# Std Dev: 0.0056

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = mean                     # replace 0 with an expression

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7130

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
# Your code here

param_dist = {
    "learning_rate": loguniform(1e-3, 0.3),
    "max_leaf_nodes": randint(16, 257),      
    "max_depth": randint(2, 11),             
    "min_samples_leaf": randint(10, 201),    
    "l2_regularization": uniform(0.0, 2.0)   
}

random_search = RandomizedSearchCV(
    estimator=HGBC_model,          # e.g. HistGradientBoostingClassifier(...) or Regressor(...)
    param_distributions=param_dist,
    n_iter=10,
    scoring="f1",             # use "f1_macro" if multiclass
    cv=skf,
    random_state=random_seed,
    n_jobs=-1
)
random_search.fit(X, y)

results = pd.DataFrame(random_search.cv_results_)
cols = [
    "mean_test_score",
    "std_test_score",
    "param_learning_rate",
    "param_max_leaf_nodes",
    "param_max_depth",
    "param_min_samples_leaf",
    "param_l2_regularization"
]

top5 = results[cols].sort_values(
    by="mean_test_score", ascending=False
).head(5)
display(top5)
# Out:
#    mean_test_score  std_test_score  param_learning_rate  param_max_leaf_nodes  \
# 0         0.711799        0.005935             0.226482                   204
# 9         0.711625        0.005605             0.049264                   190
# 2         0.711161        0.005039             0.040957                    17
# 6         0.704513        0.004682             0.014329                    66
# 8         0.696906        0.003153             0.009010                   145
#
#    param_max_depth  param_min_samples_leaf  param_l2_regularization
# 0                9                      30                 0.749080
# 9                9                      44                 0.482051
# 2                6                      97                 0.285734
# 6                6                     144                 1.966462
# 8                6                      93                 1.126576

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = random_search.best_score_                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7118

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Your code here

def objective(trial):
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 16, 256),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 200),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 2.0)
    }

    model = HistGradientBoostingClassifier(
        random_state=random_seed,
        **params
    )

    scores = cross_val_score(
        model,
        X, y,
        cv=skf,          # same StratifiedKFold object as before
        scoring="f1"     # or "f1_macro" if multiclass
    )

    return scores.mean()

study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=100)

df = study.trials_dataframe()

cols = [
    "value",  # F1 score
    "params_learning_rate",
    "params_max_leaf_nodes",
    "params_max_depth",
    "params_min_samples_leaf",
    "params_l2_regularization"
]

top5 = df[cols].sort_values(by="value", ascending=False).head(5)
display(top5)
# Out:
# [I 2026-03-21 21:54:13,527] A new study created in memory with name: no-name-89a5e3fc-5ebf-4f0e-a75b-f4b80eb27c81
# [I 2026-03-21 21:54:19,126] Trial 0 finished with value: 0.6424496818702286 and parameters: {'learning_rate': 0.014681254498990525, 'max_leaf_nodes': 83, 'max_depth': 7, 'min_samples_leaf': 37, 'l2_regularization': 1.1987997882277488}. Best is trial 0 with value: 0.6424496818702286.
# [I 2026-03-21 21:54:25,984] Trial 1 finished with value: 0.6066377556847894 and parameters: {'learning_rate': 0.010692004154228862, 'max_leaf_nodes': 64, 'max_depth': 9, 'min_samples_leaf': 100, 'l2_regularization': 0.21116523607771875}. Best is trial 0 with value: 0.6424496818702286.
# [I 2026-03-21 21:54:33,140] Trial 2 finished with value: 0.0 and parameters: {'learning_rate': 0.002096015613997585, 'max_leaf_nodes': 208, 'max_depth': 9, 'min_samples_leaf': 105, 'l2_regularization': 0.8195052715168012}. Best is trial 0 with value: 0.6424496818702286.
# [I 2026-03-21 21:54:37,528] Trial 3 finished with value: 0.7036963901600315 and parameters: {'learning_rate': 0.08127962600351983, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 99, 'l2_regularization': 0.8156563684034153}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:39,895] Trial 4 finished with value: 0.0 and parameters: {'learning_rate': 0.002348918407700577, 'max_leaf_nodes': 192, 'max_depth': 5, 'min_samples_leaf': 17, 'l2_regularization': 1.77535332108067}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:42,235] Trial 5 finished with value: 0.6162838720565872 and parameters: {'learning_rate': 0.01361739053210158, 'max_leaf_nodes': 250, 'max_depth': 5, 'min_samples_leaf': 49, 'l2_regularization': 1.9682634748664047}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:44,763] Trial 6 finished with value: 0.0 and parameters: {'learning_rate': 0.0036552639110357305, 'max_leaf_nodes': 31, 'max_depth': 5, 'min_samples_leaf': 132, 'l2_regularization': 1.9487296007808468}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:47,847] Trial 7 finished with value: 0.0 and parameters: {'learning_rate': 0.002393328501775801, 'max_leaf_nodes': 100, 'max_depth': 6, 'min_samples_leaf': 179, 'l2_regularization': 1.017936157875584}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:49,217] Trial 8 finished with value: 0.569833520735878 and parameters: {'learning_rate': 0.010594293724713037, 'max_leaf_nodes': 238, 'max_depth': 3, 'min_samples_leaf': 134, 'l2_regularization': 1.727942507090578}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:54,662] Trial 9 finished with value: 0.5366757456621774 and parameters: {'learning_rate': 0.007739838582391525, 'max_leaf_nodes': 223, 'max_depth': 7, 'min_samples_leaf': 54, 'l2_regularization': 1.7353614160991853}. Best is trial 3 with value: 0.7036963901600315.
# [I 2026-03-21 21:54:58,729] Trial 10 finished with value: 0.7061099733588954 and parameters: {'learning_rate': 0.11597901499677168, 'max_leaf_nodes': 151, 'max_depth': 10, 'min_samples_leaf': 188, 'l2_regularization': 0.44097028611470723}. Best is trial 10 with value: 0.7061099733588954.
# [I 2026-03-21 21:55:02,925] Trial 11 finished with value: 0.7062783451262123 and parameters: {'learning_rate': 0.12450106440924767, 'max_leaf_nodes': 153, 'max_depth': 10, 'min_samples_leaf': 187, 'l2_regularization': 0.3497853013031277}. Best is trial 11 with value: 0.7062783451262123.
# [I 2026-03-21 21:55:05,404] Trial 12 finished with value: 0.7070871967200052 and parameters: {'learning_rate': 0.2762981603488702, 'max_leaf_nodes': 156, 'max_depth': 10, 'min_samples_leaf': 199, 'l2_regularization': 0.12607280287446093}. Best is trial 12 with value: 0.7070871967200052.
# [I 2026-03-21 21:55:08,436] Trial 13 finished with value: 0.708269880923933 and parameters: {'learning_rate': 0.22721800768362868, 'max_leaf_nodes': 156, 'max_depth': 10, 'min_samples_leaf': 198, 'l2_regularization': 0.011721103420836432}. Best is trial 13 with value: 0.708269880923933.
# [I 2026-03-21 21:55:11,710] Trial 14 finished with value: 0.7088878628308098 and parameters: {'learning_rate': 0.29349182449695027, 'max_leaf_nodes': 121, 'max_depth': 10, 'min_samples_leaf': 157, 'l2_regularization': 0.01216251460438278}. Best is trial 14 with value: 0.7088878628308098.
# [I 2026-03-21 21:55:12,759] Trial 15 finished with value: 0.6443146655727299 and parameters: {'learning_rate': 0.04136047753433647, 'max_leaf_nodes': 130, 'max_depth': 2, 'min_samples_leaf': 160, 'l2_regularization': 0.02225102067593939}. Best is trial 14 with value: 0.7088878628308098.
# [I 2026-03-21 21:55:15,237] Trial 16 finished with value: 0.7095529092531765 and parameters: {'learning_rate': 0.27236054408620464, 'max_leaf_nodes': 116, 'max_depth': 8, 'min_samples_leaf': 156, 'l2_regularization': 0.5208664369623501}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:20,654] Trial 17 finished with value: 0.6982422558404767 and parameters: {'learning_rate': 0.05638146183618339, 'max_leaf_nodes': 114, 'max_depth': 8, 'min_samples_leaf': 146, 'l2_regularization': 0.5393757685899273}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:26,229] Trial 18 finished with value: 0.6755227320320638 and parameters: {'learning_rate': 0.029714054907045654, 'max_leaf_nodes': 181, 'max_depth': 8, 'min_samples_leaf': 150, 'l2_regularization': 0.6131360841936044}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:28,832] Trial 19 finished with value: 0.7091668258428381 and parameters: {'learning_rate': 0.16182316129773522, 'max_leaf_nodes': 21, 'max_depth': 9, 'min_samples_leaf': 170, 'l2_regularization': 1.2924309234910722}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:31,736] Trial 20 finished with value: 0.7084571813220147 and parameters: {'learning_rate': 0.15001496679536577, 'max_leaf_nodes': 30, 'max_depth': 7, 'min_samples_leaf': 121, 'l2_regularization': 1.4283782524012207}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:34,862] Trial 21 finished with value: 0.7065835659007661 and parameters: {'learning_rate': 0.21234925501204796, 'max_leaf_nodes': 59, 'max_depth': 9, 'min_samples_leaf': 167, 'l2_regularization': 1.331173117599659}. Best is trial 16 with value: 0.7095529092531765.
# [I 2026-03-21 21:55:37,414] Trial 22 finished with value: 0.7110439188205872 and parameters: {'learning_rate': 0.2945051620509724, 'max_leaf_nodes': 18, 'max_depth': 9, 'min_samples_leaf': 172, 'l2_regularization': 0.7766790190873664}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:55:40,436] Trial 23 finished with value: 0.7004777021714481 and parameters: {'learning_rate': 0.07053396542062863, 'max_leaf_nodes': 19, 'max_depth': 8, 'min_samples_leaf': 175, 'l2_regularization': 0.8493483754141937}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:55:46,375] Trial 24 finished with value: 0.6784174520573167 and parameters: {'learning_rate': 0.02622742912198102, 'max_leaf_nodes': 44, 'max_depth': 9, 'min_samples_leaf': 77, 'l2_regularization': 1.074302195164634}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:55:48,949] Trial 25 finished with value: 0.7077809824921291 and parameters: {'learning_rate': 0.1561863186233044, 'max_leaf_nodes': 17, 'max_depth': 6, 'min_samples_leaf': 140, 'l2_regularization': 0.6690228026953718}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:55:54,972] Trial 26 finished with value: 0.7060363123798048 and parameters: {'learning_rate': 0.08827679786341855, 'max_leaf_nodes': 88, 'max_depth': 9, 'min_samples_leaf': 118, 'l2_regularization': 1.3579418228097992}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:55:57,911] Trial 27 finished with value: 0.7083078239243124 and parameters: {'learning_rate': 0.19298878673292327, 'max_leaf_nodes': 50, 'max_depth': 7, 'min_samples_leaf': 170, 'l2_regularization': 1.2002776211444852}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:03,939] Trial 28 finished with value: 0.0 and parameters: {'learning_rate': 0.0011883285732960636, 'max_leaf_nodes': 73, 'max_depth': 8, 'min_samples_leaf': 154, 'l2_regularization': 1.5037074490065203}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:09,133] Trial 29 finished with value: 0.6913172176609328 and parameters: {'learning_rate': 0.04508719050659623, 'max_leaf_nodes': 90, 'max_depth': 7, 'min_samples_leaf': 84, 'l2_regularization': 0.7045479775682376}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:13,195] Trial 30 finished with value: 0.7068023018012571 and parameters: {'learning_rate': 0.10608388392698936, 'max_leaf_nodes': 49, 'max_depth': 9, 'min_samples_leaf': 184, 'l2_regularization': 0.3951457312887593}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:15,873] Trial 31 finished with value: 0.7069455551269723 and parameters: {'learning_rate': 0.29864476269795226, 'max_leaf_nodes': 109, 'max_depth': 10, 'min_samples_leaf': 160, 'l2_regularization': 0.25738478797525793}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:18,869] Trial 32 finished with value: 0.7074981608951922 and parameters: {'learning_rate': 0.170972468184346, 'max_leaf_nodes': 130, 'max_depth': 9, 'min_samples_leaf': 164, 'l2_regularization': 1.2088040711559827}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:21,112] Trial 33 finished with value: 0.7084538177367066 and parameters: {'learning_rate': 0.26370664405298233, 'max_leaf_nodes': 74, 'max_depth': 10, 'min_samples_leaf': 126, 'l2_regularization': 0.94733333920151}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:24,322] Trial 34 finished with value: 0.7080157549378041 and parameters: {'learning_rate': 0.18419828897699742, 'max_leaf_nodes': 175, 'max_depth': 9, 'min_samples_leaf': 108, 'l2_regularization': 0.5324115335790924}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:26,199] Trial 35 finished with value: 0.7081809613566226 and parameters: {'learning_rate': 0.29962053713046904, 'max_leaf_nodes': 117, 'max_depth': 8, 'min_samples_leaf': 144, 'l2_regularization': 0.16274004695004804}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:29,038] Trial 36 finished with value: 0.7078824886405986 and parameters: {'learning_rate': 0.11915762760567969, 'max_leaf_nodes': 33, 'max_depth': 10, 'min_samples_leaf': 177, 'l2_regularization': 0.796000587495712}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:32,099] Trial 37 finished with value: 0.7031520596459431 and parameters: {'learning_rate': 0.08257085239192605, 'max_leaf_nodes': 140, 'max_depth': 8, 'min_samples_leaf': 193, 'l2_regularization': 1.1173961134362795}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:33,972] Trial 38 finished with value: 0.7024834412673958 and parameters: {'learning_rate': 0.15109296856927754, 'max_leaf_nodes': 102, 'max_depth': 4, 'min_samples_leaf': 152, 'l2_regularization': 1.5909310194129869}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:36,451] Trial 39 finished with value: 0.7087897201741878 and parameters: {'learning_rate': 0.22463246468261588, 'max_leaf_nodes': 74, 'max_depth': 9, 'min_samples_leaf': 135, 'l2_regularization': 0.28048461085336795}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:39,882] Trial 40 finished with value: 0.34297522522003365 and parameters: {'learning_rate': 0.004581211265302595, 'max_leaf_nodes': 38, 'max_depth': 7, 'min_samples_leaf': 172, 'l2_regularization': 0.9207083861820182}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:42,482] Trial 41 finished with value: 0.7082072296057409 and parameters: {'learning_rate': 0.22139973542742208, 'max_leaf_nodes': 67, 'max_depth': 9, 'min_samples_leaf': 132, 'l2_regularization': 0.2787970122827053}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:45,314] Trial 42 finished with value: 0.7075933670017316 and parameters: {'learning_rate': 0.19907559934978936, 'max_leaf_nodes': 81, 'max_depth': 9, 'min_samples_leaf': 161, 'l2_regularization': 0.468541953777611}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:47,361] Trial 43 finished with value: 0.70710897458484 and parameters: {'learning_rate': 0.13347360429498276, 'max_leaf_nodes': 16, 'max_depth': 9, 'min_samples_leaf': 138, 'l2_regularization': 0.18841757523921532}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:52,766] Trial 44 finished with value: 0.7057763333910639 and parameters: {'learning_rate': 0.0981034574573501, 'max_leaf_nodes': 121, 'max_depth': 10, 'min_samples_leaf': 108, 'l2_regularization': 0.32703371847812146}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:54,880] Trial 45 finished with value: 0.7090927807410811 and parameters: {'learning_rate': 0.2996422275003954, 'max_leaf_nodes': 57, 'max_depth': 10, 'min_samples_leaf': 182, 'l2_regularization': 0.09708828231484273}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:56:56,984] Trial 46 finished with value: 0.7062666559797697 and parameters: {'learning_rate': 0.2986681557051828, 'max_leaf_nodes': 57, 'max_depth': 10, 'min_samples_leaf': 184, 'l2_regularization': 0.08969277127707798}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:02,179] Trial 47 finished with value: 0.7005173157165491 and parameters: {'learning_rate': 0.06001768983626492, 'max_leaf_nodes': 95, 'max_depth': 10, 'min_samples_leaf': 182, 'l2_regularization': 0.7865171577794369}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:04,385] Trial 48 finished with value: 0.7091708053130766 and parameters: {'learning_rate': 0.24147310587233198, 'max_leaf_nodes': 28, 'max_depth': 10, 'min_samples_leaf': 199, 'l2_regularization': 0.06407214510434969}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:07,307] Trial 49 finished with value: 0.621940239748762 and parameters: {'learning_rate': 0.01467269046945294, 'max_leaf_nodes': 30, 'max_depth': 6, 'min_samples_leaf': 192, 'l2_regularization': 0.08508105775791838}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:09,702] Trial 50 finished with value: 0.7085287329839914 and parameters: {'learning_rate': 0.14257212342133996, 'max_leaf_nodes': 25, 'max_depth': 8, 'min_samples_leaf': 196, 'l2_regularization': 0.5786475923389605}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:12,141] Trial 51 finished with value: 0.7095897594508733 and parameters: {'learning_rate': 0.23348895642048742, 'max_leaf_nodes': 44, 'max_depth': 10, 'min_samples_leaf': 172, 'l2_regularization': 0.01740042877152155}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:14,497] Trial 52 finished with value: 0.7090895437420592 and parameters: {'learning_rate': 0.23438056966263116, 'max_leaf_nodes': 44, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 0.2012718101168925}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:17,263] Trial 53 finished with value: 0.7092685008913573 and parameters: {'learning_rate': 0.17192548195523186, 'max_leaf_nodes': 37, 'max_depth': 10, 'min_samples_leaf': 173, 'l2_regularization': 0.09397649216208279}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:19,830] Trial 54 finished with value: 0.7103757138318813 and parameters: {'learning_rate': 0.17742935441314273, 'max_leaf_nodes': 36, 'max_depth': 10, 'min_samples_leaf': 30, 'l2_regularization': 0.4317323629107135}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:23,107] Trial 55 finished with value: 0.7110344042460748 and parameters: {'learning_rate': 0.11604870986646139, 'max_leaf_nodes': 39, 'max_depth': 10, 'min_samples_leaf': 10, 'l2_regularization': 0.46435168327523435}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:27,286] Trial 56 finished with value: 0.7086900319884339 and parameters: {'learning_rate': 0.07031857428414622, 'max_leaf_nodes': 40, 'max_depth': 10, 'min_samples_leaf': 16, 'l2_regularization': 0.4832425407866926}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:31,954] Trial 57 finished with value: 0.708822789034331 and parameters: {'learning_rate': 0.10651449924613436, 'max_leaf_nodes': 51, 'max_depth': 10, 'min_samples_leaf': 23, 'l2_regularization': 0.6653529053797764}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:35,789] Trial 58 finished with value: 0.6765624751167791 and parameters: {'learning_rate': 0.023472858506257542, 'max_leaf_nodes': 38, 'max_depth': 9, 'min_samples_leaf': 34, 'l2_regularization': 0.38323421144235614}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:39,586] Trial 59 finished with value: 0.7077907630473766 and parameters: {'learning_rate': 0.17878237858872295, 'max_leaf_nodes': 213, 'max_depth': 10, 'min_samples_leaf': 54, 'l2_regularization': 0.7273428001297596}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:43,608] Trial 60 finished with value: 0.7081179698419923 and parameters: {'learning_rate': 0.12605225447361237, 'max_leaf_nodes': 64, 'max_depth': 9, 'min_samples_leaf': 21, 'l2_regularization': 0.5602499125376194}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:45,585] Trial 61 finished with value: 0.7102798858990893 and parameters: {'learning_rate': 0.24297774767797686, 'max_leaf_nodes': 33, 'max_depth': 10, 'min_samples_leaf': 12, 'l2_regularization': 0.02771756877210374}. Best is trial 22 with value: 0.7110439188205872.
# [I 2026-03-21 21:57:47,656] Trial 62 finished with value: 0.7122358396128053 and parameters: {'learning_rate': 0.1915481099770448, 'max_leaf_nodes': 24, 'max_depth': 10, 'min_samples_leaf': 42, 'l2_regularization': 0.015463636279714504}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:49,619] Trial 63 finished with value: 0.709825499141767 and parameters: {'learning_rate': 0.2164577702641543, 'max_leaf_nodes': 24, 'max_depth': 10, 'min_samples_leaf': 34, 'l2_regularization': 0.006198815797809239}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:51,465] Trial 64 finished with value: 0.7097158330066733 and parameters: {'learning_rate': 0.21418165196051822, 'max_leaf_nodes': 25, 'max_depth': 10, 'min_samples_leaf': 11, 'l2_regularization': 0.011055585598311362}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:53,705] Trial 65 finished with value: 0.7101124283409995 and parameters: {'learning_rate': 0.1944001750583622, 'max_leaf_nodes': 23, 'max_depth': 10, 'min_samples_leaf': 10, 'l2_regularization': 0.14856512124921675}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:56,111] Trial 66 finished with value: 0.7113008713260427 and parameters: {'learning_rate': 0.1453344529701449, 'max_leaf_nodes': 22, 'max_depth': 10, 'min_samples_leaf': 33, 'l2_regularization': 0.15946843635646363}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:56,974] Trial 67 finished with value: 0.3736846934172979 and parameters: {'learning_rate': 0.011083014111790782, 'max_leaf_nodes': 32, 'max_depth': 2, 'min_samples_leaf': 42, 'l2_regularization': 0.15335031746042496}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:57:58,552] Trial 68 finished with value: 0.6987882990291153 and parameters: {'learning_rate': 0.09534401646784145, 'max_leaf_nodes': 21, 'max_depth': 4, 'min_samples_leaf': 27, 'l2_regularization': 0.23447865889656153}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:02,072] Trial 69 finished with value: 0.7094585950846952 and parameters: {'learning_rate': 0.15109069882539686, 'max_leaf_nodes': 50, 'max_depth': 9, 'min_samples_leaf': 62, 'l2_regularization': 0.33728862915656704}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:04,788] Trial 70 finished with value: 0.6914290326118502 and parameters: {'learning_rate': 0.042574115515773496, 'max_leaf_nodes': 17, 'max_depth': 9, 'min_samples_leaf': 29, 'l2_regularization': 0.19948070146873265}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:07,224] Trial 71 finished with value: 0.7120726856512556 and parameters: {'learning_rate': 0.19217424690246165, 'max_leaf_nodes': 25, 'max_depth': 10, 'min_samples_leaf': 41, 'l2_regularization': 0.1409008126539965}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:10,639] Trial 72 finished with value: 0.7100375538440042 and parameters: {'learning_rate': 0.12368787096201406, 'max_leaf_nodes': 32, 'max_depth': 10, 'min_samples_leaf': 11, 'l2_regularization': 0.13962839787178033}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:12,946] Trial 73 finished with value: 0.710723525291517 and parameters: {'learning_rate': 0.18022759984071662, 'max_leaf_nodes': 25, 'max_depth': 10, 'min_samples_leaf': 45, 'l2_regularization': 0.4190198634410931}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:16,017] Trial 74 finished with value: 0.7092549181123002 and parameters: {'learning_rate': 0.1626812710563082, 'max_leaf_nodes': 42, 'max_depth': 10, 'min_samples_leaf': 41, 'l2_regularization': 0.4027675443373244}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:19,982] Trial 75 finished with value: 0.7074096340079613 and parameters: {'learning_rate': 0.11457461104650024, 'max_leaf_nodes': 54, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 0.32355602704707753}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:21,792] Trial 76 finished with value: 0.7052435777868318 and parameters: {'learning_rate': 0.07655635674821548, 'max_leaf_nodes': 16, 'max_depth': 9, 'min_samples_leaf': 65, 'l2_regularization': 0.4352557984481923}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:23,548] Trial 77 finished with value: 0.7093673147767193 and parameters: {'learning_rate': 0.2577077175699567, 'max_leaf_nodes': 34, 'max_depth': 10, 'min_samples_leaf': 43, 'l2_regularization': 0.26913498451377377}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:26,237] Trial 78 finished with value: 0.7092092896369933 and parameters: {'learning_rate': 0.140272357540665, 'max_leaf_nodes': 46, 'max_depth': 10, 'min_samples_leaf': 19, 'l2_regularization': 0.2436022985131962}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:29,040] Trial 79 finished with value: 0.7089214470148482 and parameters: {'learning_rate': 0.18019419958011573, 'max_leaf_nodes': 254, 'max_depth': 9, 'min_samples_leaf': 27, 'l2_regularization': 0.6337505537938535}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:31,538] Trial 80 finished with value: 0.3851196091328269 and parameters: {'learning_rate': 0.0054513823456708455, 'max_leaf_nodes': 26, 'max_depth': 9, 'min_samples_leaf': 86, 'l2_regularization': 0.8757770783216972}. Best is trial 62 with value: 0.7122358396128053.
# [I 2026-03-21 21:58:33,184] Trial 81 finished with value: 0.7130356357790146 and parameters: {'learning_rate': 0.19350216064111783, 'max_leaf_nodes': 22, 'max_depth': 10, 'min_samples_leaf': 13, 'l2_regularization': 0.14280798309775636}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:34,841] Trial 82 finished with value: 0.7104737814163323 and parameters: {'learning_rate': 0.2555875002297565, 'max_leaf_nodes': 35, 'max_depth': 10, 'min_samples_leaf': 37, 'l2_regularization': 0.301119414683907}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:36,679] Trial 83 finished with value: 0.7119177378838037 and parameters: {'learning_rate': 0.19477977916999137, 'max_leaf_nodes': 21, 'max_depth': 10, 'min_samples_leaf': 37, 'l2_regularization': 0.47049576799665543}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:38,649] Trial 84 finished with value: 0.710498152681238 and parameters: {'learning_rate': 0.19760887214835826, 'max_leaf_nodes': 21, 'max_depth': 10, 'min_samples_leaf': 59, 'l2_regularization': 0.30111537686108614}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:40,239] Trial 85 finished with value: 0.7117621209911656 and parameters: {'learning_rate': 0.20227587591142354, 'max_leaf_nodes': 16, 'max_depth': 9, 'min_samples_leaf': 60, 'l2_regularization': 0.4770885879296993}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:42,527] Trial 86 finished with value: 0.709742551703423 and parameters: {'learning_rate': 0.13802123358426, 'max_leaf_nodes': 27, 'max_depth': 9, 'min_samples_leaf': 47, 'l2_regularization': 0.475238107934802}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:44,376] Trial 87 finished with value: 0.7075212903838856 and parameters: {'learning_rate': 0.10454004969011647, 'max_leaf_nodes': 18, 'max_depth': 9, 'min_samples_leaf': 69, 'l2_regularization': 0.7409173434389675}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:49,317] Trial 88 finished with value: 0.0 and parameters: {'learning_rate': 0.0015674515697045323, 'max_leaf_nodes': 235, 'max_depth': 8, 'min_samples_leaf': 50, 'l2_regularization': 0.3745861042308577}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:50,802] Trial 89 finished with value: 0.7105808807091194 and parameters: {'learning_rate': 0.16463072951214275, 'max_leaf_nodes': 16, 'max_depth': 5, 'min_samples_leaf': 39, 'l2_regularization': 0.6037685972920679}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:52,305] Trial 90 finished with value: 0.7100431257817672 and parameters: {'learning_rate': 0.25842467041528827, 'max_leaf_nodes': 25, 'max_depth': 9, 'min_samples_leaf': 46, 'l2_regularization': 0.5074586765156828}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:53,667] Trial 91 finished with value: 0.7083894381078256 and parameters: {'learning_rate': 0.15898752833666818, 'max_leaf_nodes': 17, 'max_depth': 4, 'min_samples_leaf': 37, 'l2_regularization': 0.5995202892220622}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:55,293] Trial 92 finished with value: 0.7084952483510355 and parameters: {'learning_rate': 0.21055886004747063, 'max_leaf_nodes': 41, 'max_depth': 5, 'min_samples_leaf': 55, 'l2_regularization': 0.6404347892053237}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:57,362] Trial 93 finished with value: 0.7035133170719694 and parameters: {'learning_rate': 0.08665568170429905, 'max_leaf_nodes': 27, 'max_depth': 5, 'min_samples_leaf': 33, 'l2_regularization': 0.5897648088912538}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:58:59,182] Trial 94 finished with value: 0.7101847813605926 and parameters: {'learning_rate': 0.13069238705728398, 'max_leaf_nodes': 30, 'max_depth': 5, 'min_samples_leaf': 25, 'l2_regularization': 0.5155607252906095}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:59:00,808] Trial 95 finished with value: 0.7090843535704972 and parameters: {'learning_rate': 0.19579815290425454, 'max_leaf_nodes': 21, 'max_depth': 6, 'min_samples_leaf': 39, 'l2_regularization': 0.061243356683878536}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:59:03,249] Trial 96 finished with value: 0.7119473178593436 and parameters: {'learning_rate': 0.1617737938849388, 'max_leaf_nodes': 29, 'max_depth': 10, 'min_samples_leaf': 19, 'l2_regularization': 1.8543306019089754}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:59:04,862] Trial 97 finished with value: 0.7101557566550009 and parameters: {'learning_rate': 0.2672163872893329, 'max_leaf_nodes': 38, 'max_depth': 10, 'min_samples_leaf': 16, 'l2_regularization': 1.8598881977562793}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:59:08,751] Trial 98 finished with value: 0.7093111688870697 and parameters: {'learning_rate': 0.11276872324584661, 'max_leaf_nodes': 47, 'max_depth': 10, 'min_samples_leaf': 16, 'l2_regularization': 1.0319296884400906}. Best is trial 81 with value: 0.7130356357790146.
# [I 2026-03-21 21:59:13,834] Trial 99 finished with value: 0.696474348498237 and parameters: {'learning_rate': 0.03620190516655639, 'max_leaf_nodes': 60, 'max_depth': 10, 'min_samples_leaf': 22, 'l2_regularization': 1.6405327705023716}. Best is trial 81 with value: 0.7130356357790146.
#        value  params_learning_rate  params_max_leaf_nodes  params_max_depth  \
# 81  0.713036              0.193502                     22                10
# 62  0.712236              0.191548                     24                10
# 71  0.712073              0.192174                     25                10
# 96  0.711947              0.161774                     29                10
# 83  0.711918              0.194780                     21                10
#
#     params_min_samples_leaf  params_l2_regularization
# 81                       13                  0.142808
# 62                       42                  0.015464
# 71                       41                  0.140901
# 96                       19                  1.854331
# 83                       37                  0.470496

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = study.best_value                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7130

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
# Your code here
from sklearn.metrics import precision_score, recall_score, f1_score, balanced_accuracy_score

best_params = {
    "model__learning_rate": study.best_params["learning_rate"],
    "model__max_leaf_nodes": study.best_params["max_leaf_nodes"],
    "model__max_depth": study.best_params["max_depth"],
    "model__min_samples_leaf": study.best_params["min_samples_leaf"],
    "model__l2_regularization": study.best_params["l2_regularization"]
}

pipelined_model.fit(X, y)

pipelined_model.named_steps
y_pred = pipelined_model.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
balanced_acc = balanced_accuracy_score(y_test, y_pred)

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = balanced_acc                     # replace 0 with your answer, use variable or expression from above

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8626

# %%
 # Your answer here

a4b = precision                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.6308

# %%
 # Your answer here

a4c = recall                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8888

# %% [markdown]
# ## Problem 5: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ###  Problem 5 Graded Question (multiple choice)
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# (1) The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# (2) The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# (3) The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.

# %%
 # Your answer here

a5 = 2                     # replace 0 with one of 1, 2, or 3

# %%
# DO NOT change this cell in any way

print(f'a5 = {a5}')
# Out:
# a5 = 2

# %% [markdown]
# ### Appendix One: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
