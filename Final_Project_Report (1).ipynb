# %% [markdown]
# # Project Final Report
#
# ### Due: Midnight on April 27th (2-hour grace period) — 50 points
#
# ### No late submissions will be accepted.
#
#
# ## Overview
#
# Your final submission consists of **two components**:
#
#
# ### 1. Team Final Report Notebook [50 pts]
#
# Complete all sections of this notebook to document your final decisions, results, and broader context.
#
# You will write a **technical report** following standard conventions. Useful references include:
# - [CMU guide to structure](https://www.stat.cmu.edu/~brian/701/notes/paper-structure.pdf)
# - [Data science report example](https://www.projectpro.io/article/data-science-project-report/620)
# - The Checklist in this week’s Blackboard Lesson (aligned with HOML)
#
# Your audience is **technically literate but unfamiliar with your work**—for example, your manager or other data scientists. Your report should be clear, precise, and well-organized, combining explanation, visualizations, and interpretation.
#
# This Final Report is distinct from Milestone 2:
#
# - **Milestone 2** serves as a repository of your working code and experiments
# - **This Final Report** presents a clear, structured summary of your project for a professional audience
#
# > **Important:**
# > - Do **not** assume that readers of this report are familiar with Milestone 2. Your report should stand on its own.
# > - Do not include full code or code cells in this notebook. All code was submitted in Milestone 2. This report should focus on explanation, results, and interpretation.
# > - **Do not add, delete, or move cells in this notebook.** Each answer must be written entirely within its assigned Markdown cell.
# > - All answers should be inserted directly under the appropriate `Answer:` prompt. Delete the sentence "Replace this sentence with your answer" and replace it with your response.
# > - You may use any appropriate Markdown formatting (paragraphs, lists, tables, inserted graphics, LaTeX, etc.).
# > - Submit this notebook as a group via your team leader’s Gradescope account.
#
#
# ### 2. Individual Assessment [0 points]
#
# Each team member must **individually** complete the Final Project Individual Assessment Form (similar to Milestone 1), sign it, and upload it via their own Gradescope account.
#
# **Due:** May 5th @ 2:00 AM
#
#
#
# ## Submission Checklist
#
# - Final Report Notebook — submitted by team leader
# - Individual Assessment Form — submitted by each team member

# %% [markdown]
# ## 1. Executive Summary [4 pts]
#
# Write a 300–400 word executive summary for a **non-technical audience**, such as business stakeholders in a real estate company.
#
# Your summary should explain:
# - the objective of the project
# - key insights about the data
# - the most important findings, including a plain-language description of model performance
# - a clear recommendation or takeaway
#
# Avoid technical detail and jargon. Focus on what matters and why.
#
# **1.1 Answer:**
# The goal of this project was to develop a model that could predict residential property values using a cleaned Zillow dataset. The dataset included a mix of structural, geographic, and property-related features such as square footage, number of rooms, and location indicators. After completing exploratory data analysis and preprocessing, several regression models were evaluated to determine which approach produced the most accurate predictions.
#
# Three baseline models were initially tested: Linear Regression, Ridge Regression, and Random Forest. The results showed that Random Forest consistently outperformed the linear models, suggesting that the relationships between the features and property values were not purely linear and required a more flexible modeling approach. Additional steps were taken to improve model performance, including feature engineering and feature selection. New features such as squared terms and ratios were introduced, but these only resulted in minimal improvements. In contrast, reducing the number of features through selection methods actually led to worse performance, indicating that the model benefited from having access to a broader set of variables.
#
# Hyperparameter tuning was then applied to refine each model. While tuning slightly improved the performance of the Random Forest model, it remained the best-performing approach overall. The final tuned Random Forest model achieved a mean absolute error of approximately $135,000 on cross-validation, with similar performance on the hold-out test set. This indicates that, on average, the model’s predictions were within that range of the true property values.
#
# Overall, the results suggest that tree-based models are better suited for this dataset, as they are able to capture more complex patterns than linear models. While the prediction error is still relatively large, the model provides a reasonable estimate of property values and demonstrates the importance of model selection when working with real-world housing data.
#
# **Redo without jargon**
#
# The objective of this project is to have a better understanding of the factors that influence residental property values using a Zillow dataset. The dataset included a mix of structural, geographic, and property-related features such as square footage, number of rooms, and location indicators.
#
# From the initial analyis, we found that not all features of a property contributed equally to the home's value. One exploration of using more simplier methods shows that there is no singluar feature that contributes to the value, but has a more complex correlation. Having a flexible approach helped capture a more complex pattern in the data and produced better results. This suggests that the home prices are influenced by a mix of factors instead of a simple, predictable trend.
#
# Also, we explored ways to improve the accuracy of the estimates and found that combining or transforming existing data only led to small improvements. Interestingly, reducing the number of factors used in the model made the model worse which indicates that having multiple property details helps produce more accurate estimates, even for individual factors that seem less important on their own. After fine-tuning the best performing parameters, we are able to achieve the strongest results. The final tuned model helps achieve estimates within about $135,000 of the actual property value. Even though this seems like a large margin, it is reasonable to give natural variability to the home proces and the limitations of the dataset.
#
# Overall, the model displays that models need to be more flexible to have a better suited estimating for property values because they have to account for more complex housing markets. This variability helps reasonably estimate property values and demonstrates the importance of model selection when working with real-world housing data. A key takeaway is that choosing the right approach matters more than adding complexity. This model can help support decision making by offering reliable directional insights, but it should be combined with marketing expertise and additiona data for the most accurate pricing strategies

# %% [markdown]
# ## 2. Introduction [3 pts]
#
# Introduce the topic, context, and goals of your project.
#
# You may imagine that this project was completed for a **real estate company with a small in-house data science team**.
#
# Include all of the following:
#
# - Clearly introduce the topic and context of your project
# - Describe the problem you are addressing (the problem statement) and the overall motivation for solving it
# - Clearly state the objectives and goals of your analysis (as different from the motivation)
#
# **2.1 Answer:**
# The purpose of this project is to predict residential property values using a dataset from Zillow that includes information about housing characteristics, location, and property features. Accurately estimating property values is important in real estate for both buyers and sellers, as well as for financial institutions and policymakers. Having a reliable model can help support better decision-making when it comes to pricing, investment, and understanding market trends.
#
# The dataset used in this project contains a variety of features such as square footage, number of bedrooms and bathrooms, property type, and geographic information. Since real-world data is rarely clean, the project began with cleaning and preprocessing steps to handle missing values and prepare the data for analysis. After this, exploratory data analysis was conducted to better understand the relationships between features and the target variable, which is the property’s assessed value.
#
# The main objective of this project is to compare different regression models and determine which one provides the most accurate predictions. In addition to testing baseline models, the project also explores feature engineering, feature selection, and hyperparameter tuning to see how these steps impact performance. By evaluating these different approaches, the goal is to identify a model that balances accuracy and generalization when applied to unseen data.

# %% [markdown]
# ## 3. Data Description [3 pts]
#
# Describe the dataset used in your analysis.
#
# Include:
# - the source of the dataset
# - the number of observations (samples) and features
# - the types of variables
# - the target variable
# - missing values or other important issues in the raw data
#
# **3.1 Answer:**
# The dataset used in this project comes from Zillow and contains information about residential properties, including structural features, location data, and property characteristics. Some of the key variables include finished square footage, number of bedrooms and bathrooms, year built, geographic coordinates, and other property-related attributes. The target variable for this analysis is taxvaluedollarcnt, which represents the assessed value of each property.
#
# As is common with real-world datasets, the data contained missing values and a mix of numerical and categorical features. There are 72,193 observations and 27 features in our cleaned zillow dataset. To prepare the data for modeling, several preprocessing steps were performed. Missing values were handled using imputation, and categorical variables were encoded so they could be used in machine learning models. These steps ensured that the dataset was complete and in a format suitable for analysis. The target value is the taxvaluedollarcnt, which represents the assessed value of the property in dollars.
#
# In addition to cleaning, some features were examined more closely during exploratory data analysis to understand their distributions and relationships with the target variable. Certain variables, such as square footage and bathroom count, showed stronger relationships with property value, while others appeared to have weaker or more complex effects. This initial analysis helped guide later decisions around feature engineering and model selection.
#
# Overall, the cleaned dataset gave a good starting point for building and testing models, while still reflecting the complexity and variability typically found in housing data.

# %% [markdown]
# ## 4. Methodology (What you did, and why) [20 pts]
#
# Focus on the **process and your reasoning**, not the results.
#
# Note: Each subsection (e.g., 4.1, 4.2, etc.) must be answered in its own Markdown cell.  Each subsection is worth 5 points.

# %% [markdown]
# ### 4.1 Analytical Framework
#
# Describe your overall approach.
#
# Include:
# - your overall framework
# - use of validation curves
# - choice of MAE or RMSE (as appropriate) as the primary error metric
#
# **4.1 Answer:**
# The overall approach for this project followed a standard supervised machine learning workflow for regression. Since the goal was to predict a continuous target variable (taxvaluedollarcnt), the problem was framed as a regression task. The dataset was first split into training and test sets to allow for evaluation on unseen data, and all features were standardized using the training data to ensure consistency across models while avoiding data leakage.
#
# To evaluate model performance, repeated cross-validation was used with multiple folds and repeats. This helped give a more stable estimate of model performance compared to a single train-test split, helping to reduce the impact of random variation in the data. The primary evaluation metric used throughout the project was Mean Absolute Error (MAE), since it is easy to interpret in the context of housing prices. MAE represents the average difference between predicted and actual property values, making it a useful measure for understanding how far off predictions are in real-world terms.
#
# Three different regression models were selected for comparison: Linear Regression, Ridge Regression, and Random Forest. These models were chosen to represent a range of complexity, from simple linear approaches to more flexible, nonlinear methods. This allowed for a clearer understanding of how model complexity impacts performance on this dataset.
#
# Overall, the framework focused on systematically comparing models, applying feature engineering and selection techniques, and using cross-validation to guide decisions. This step-by-step approach made it easier to identify which choices improved performance and which did not, leading to a more reliable final model.

# %% [markdown]
# ### 4.2 Data Cleaning and Preprocessing
#
# Describe how you prepared the data.
#
# Include:
# - issues in the raw data
# - handling of missing values, outliers, inconsistencies
# - key decisions and why
# - what worked and what did not work
#
# **4.2 Answer:**
# The raw dataset contained several issues that needed to be addressed before it could be used for modeling. One of the main challenges was the presence of missing values across many features. Some variables had only a small number of missing values, while others had a much higher percentage, making them less useful. Features with an excessive amount of missing data were removed, while the remaining missing values were handled using imputation methods. For numerical features, missing values were typically filled using the median, as many variables were skewed and contained outliers.
#
# Outliers were also considered during preprocessing, particularly in the target variable. Very high property values can skew the model and throw off the results, so observations with unusually large target values were removed to reduce their influence. This helped stabilize the modeling process and made evaluation metrics more representative of typical properties.
#
# Categorical features were encoded into numerical form so they could be used in machine learning models. In some cases, categorical variables were represented by numerical identifiers already, but they were still treated appropriately during preprocessing. Feature scaling was then applied using standardization, which ensured that all features were on a similar scale. This was especially important for models like Linear Regression and Ridge Regression, which are sensitive to differences in feature magnitude.
#
# Overall, the preprocessing steps focused on balancing data quality with retaining as much useful information as possible. Some decisions, such as dropping features with too many missing values, improved model stability, while others, such as handling outliers, helped prevent extreme values from dominating the results. These steps created a cleaner and more consistent dataset for the modeling process.

# %% [markdown]
# ### 4.3 Feature Engineering
#
# Describe your feature engineering.
#
# Include:
# - transformations or new features
# - why you created them
# - which were useful or not useful
# - what worked and what did not work
#
# **4.3 Answer:**
# Feature engineering was used to explore whether transforming existing variables or creating new ones could improve model performance. Based on patterns observed during exploratory data analysis, several new features were created to capture potential nonlinear relationships and interactions between variables. These included transformations such as the logarithm of lot size (log_lotsize), the square of finished square footage (sqft_squared), and a ratio of bathrooms to bedrooms (bath_bed_ratio). The goal of these features was to better represent property characteristics that might influence value but were not fully captured by the original variables.
#
# After adding these engineered features, the models were re-evaluated using the same cross-validation approach as before. The results showed that feature engineering led to only small improvements, primarily for the linear models. This suggests that the transformations helped expose some nonlinear patterns that Linear Regression and Ridge Regression could not capture on their own. However, the improvements were minimal overall.
#
# For the Random Forest model, feature engineering did not improve performance and in some cases slightly worsened it. This is likely because tree-based models can already capture nonlinear relationships and interactions between features without requiring explicit transformations. As a result, the additional engineered features were somewhat redundant for this type of model.
#
# Overall, feature engineering provided limited benefit in this project. While it offered a slight improvement for simpler models, it did not significantly impact the strongest model, which was Random Forest. This suggests the original features already had most of the useful information needed for prediction.

# %% [markdown]
# ### 4.4 Model Selection
#
# Describe how you selected your model.
#
# Include:
# - models you tried and why
# - how you evaluated generalization
# - hyperparameter tuning
# - how you chose the final model
#
# **4.4 Answer:**
# Several regression models were tested in order to determine which approach provided the most accurate and reliable predictions. The models selected for comparison were Linear Regression, Ridge Regression, and Random Forest. These were chosen to represent different levels of complexity, ranging from simple linear relationships to more flexible, nonlinear methods.
#
# Model performance was evaluated using repeated cross-validation with Mean Absolute Error (MAE) as the primary metric. This allowed for consistent comparison across models while also providing insight into how well each model generalized to unseen data. The baseline results showed that Random Forest consistently outperformed both Linear Regression and Ridge Regression, achieving a substantially lower MAE. This suggests the dataset likely contains nonlinear relationships and interactions that simpler linear models were not able to capture effectively.
#
# Additional steps were taken to refine model performance, including feature engineering, feature selection, and hyperparameter tuning. Feature engineering resulted in only minor improvements, mainly for the linear models, while feature selection reduced performance across all models. This suggested that removing features eliminated useful information rather than improving generalization. Hyperparameter tuning was then applied to each model using GridSearchCV. While tuning had little effect on Linear Regression and Ridge Regression, it provided a modest improvement for Random Forest by optimizing parameters such as tree depth and minimum sample sizes.
#
# Based on these results, the tuned Random Forest model was selected as the final model. It consistently produced the lowest MAE, showed stable performance across cross-validation, and maintained similar accuracy on the hold-out test set. Although Random Forest is less interpretable than linear models, its improved predictive performance made it the best choice for this project.

# %% [markdown]
# ## 5. Results and Evaluation (What you found, and how well it worked) [16 pts]
#
# Focus on **results, evidence, and interpretation**.
#
# Note: Each subsection (e.g., 5.1, 5.2, etc.) must be answered in its own Markdown cell.

# %% [markdown]
# ### 5.1 Model Performance (6 points)
#
# Briefly interpret what your metrics mean in practical terms.
#
# Include:
# - key metrics (e.g., RMSE, $R^2$)
# - comparison across models
# - comparison of training vs validation/test performance
#
# **5.1 Answer:**
# Model performance was evaluated using Mean Absolute Error (MAE) as the primary metric, along with cross-validation to estimate how well each model would generalize to new data. Among the three models tested, Random Forest consistently achieved the lowest MAE, both before and after tuning, making it the strongest overall performer.
#
# The final tuned Random Forest model achieved a cross-validation MAE of approximately $134,977, with a standard deviation of about $1,139. This relatively low standard deviation indicates that the model performed consistently across different folds of the data. When evaluated on the hold-out test set, the model achieved a similar MAE of approximately $134,995, suggesting that it generalized well and was not significantly overfitting to the training data.
#
# In comparison, both Linear Regression and Ridge Regression produced higher MAE values of around $151,489, indicating that their predictions were, on average, further from the true property values. The similar performance of these two models suggests that adding regularization did not meaningfully improve the linear approach for this dataset.
#
# In practical terms, an MAE of about $135,000 means that the model’s predictions are typically within that range of the actual property values. WWhile this error might seem large, it’s not unexpected given the complexity and variability of real-world housing data. Overall, the results show that the Random Forest model provides more accurate and reliable predictions compared to the linear models.

# %% [markdown]
# ### 5.2 Visualizations (5 points)
#
# Graphics should be made as screenshots and dragged into the Markdown cell. Do NOT add code cells to create graphics. Each visualization must be clearly labeled and explained in the text.
#
# Include:
# - relevant plots with titles and labels
# - explanation of what each plot shows
# - why each visualization matters
#
# **5.2 Answer:**
# Visualization 1: Baseline Model Comparison
#
# ![Baseline Model Comparison.png](attachment:a9f24c64-53ae-4f3a-83c4-602fcb9a01ef.png)
#
# This chart shows the initial comparison of the three baseline models using Mean Absolute Error (MAE). Random Forest clearly outperforms both Linear Regression and Ridge Regression, achieving a noticeably lower error. This suggests early on that a more flexible, nonlinear model is better suited for this dataset. The similar performance between Linear Regression and Ridge Regression indicates that regularization did not significantly improve the linear approach.
#
# Visualization 2: Model Performance After Feature Engineering
#
# ![Model Performance After Feature Engineering.png](attachment:202ee319-bb84-4820-bb10-fe1dd26e7ffe.png)
#
# This chart compares model performance after adding engineered features. The results show only a slight improvement for the linear models, while Random Forest remains the best-performing model with little to no change. This suggests that the engineered features provided limited additional value, particularly for the Random Forest model, which can already capture nonlinear relationships without explicit transformations.
#
# Visualization 3: Model Performance After Feature Selection
#
# ![Model Performance After Feature Selection.png](attachment:be84f027-6850-4e97-9537-ccfaced2f3f1.png)
#
# This chart shows the impact of reducing the feature set using feature selection. Performance worsened for all three models, with a noticeable increase in MAE. This indicates that removing features resulted in the loss of useful information, and that the models performed better when given access to a larger set of variables. This reinforces the idea that more complex datasets may benefit from retaining a broader range of features rather than aggressively reducing them.

# %% [markdown]
# ### 5.3 Error Analysis (5 points)
#
# Include:
# - patterns in residuals or prediction errors
# - overprediction or underprediction
# - outliers or unusual observations
# - anything surprising or worth improving
#
# **5.3 Answer:**
# Although the Random Forest model performed better than the other models, there were still noticeable prediction errors. With a mean absolute error of around $135,000, the model’s predictions can sometimes differ significantly from the actual property values. This suggests there are factors influencing housing prices that are not fully captured in the dataset.
#
# One likely source of error is the presence of extreme or high-value properties. Even though some outliers were removed during preprocessing, housing data can still contain a wide range of values, and predicting very expensive properties accurately is often more difficult. These properties may have unique characteristics or location-specific factors that are not well represented by the available features.
#
# Another possible source of error is missing or limited information about property location and surrounding factors. While the dataset includes some geographic identifiers, it may not fully capture neighborhood quality, proximity to amenities, or other external influences that can significantly impact property value. This could lead to larger errors in areas where location plays a major role.
#
# Overall, the model performs reasonably well for general predictions but may struggle with more unusual or high-value properties. These limitations highlight the challenges of working with real-world housing data and suggest that additional features or more detailed location data could help improve performance.

# %% [markdown]
# ## 6. Conclusion [4 pts]
#
# Summarize your findings and implications.
#
# Include all the following:
#
# - Clearly state your main findings and how they address your original objectives
# - Highlight any business or practical implications of your findings
# - Discuss the limitations and constraints of your analysis clearly and transparently
# - Suggest potential improvements or future directions
# - Conclude with a final recommendation addressing the business objective
#
# **6.1 Answer:**
# This project explored the use of different regression models to predict residential property values using a Zillow dataset. Throughout the process, several approaches were tested, including baseline modeling, feature engineering, feature selection, and hyperparameter tuning. Each step helped provide a better understanding of how different modeling decisions impacted performance.
#
# Among the models tested, the tuned Random Forest model consistently produced the most accurate results. It was able to capture more complex relationships in the data compared to Linear Regression and Ridge Regression, which resulted in lower prediction error. While feature engineering provided only minor improvements and feature selection reduced performance, these steps were still useful in understanding how the dataset behaves and how different techniques affect model outcomes.
#
# The final model achieved a mean absolute error of approximately $135,000, with similar performance on the test set, indicating that it generalized well to unseen data. Although this level of error is not insignificant, it reflects the inherent complexity of housing data and the limitations of the available features.
#
# Overall, this project highlights the importance of choosing the right model for the problem and carefully evaluating each step in the modeling process. If more time or data were available, future improvements could include incorporating more detailed location-based features, trying additional ensemble models such as Gradient Boosting, or further refining the feature engineering process. These steps could potentially improve prediction accuracy and provide deeper insights into the factors that influence housing prices.
